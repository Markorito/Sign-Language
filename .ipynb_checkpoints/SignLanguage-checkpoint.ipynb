# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization,Rescaling
from tensorflow.keras.callbacks import Callback
from tensorflow.keras import backend as bc
import gc

# %% [markdown]
# ### LOADING IN THE DATA

# %%
batch_size = 10
img_height = 100
img_width = 100

# %%
data_dir= r"dataset/asl_alphabet_train/asl_alphabet_train"

#Splitting the dataset into training and validation dataset
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 87000 files belonging to 29 classes.
# Using 69600 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 87000 files belonging to 29 classes.
# Using 17400 files for validation.

# %%
#Print class names
class_names = train_ds.class_names
print(len(class_names))
# Out:
# 29

# %%
#Visualizing the data
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### PREPROCESSING THE DATA

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#Defining some preprocessing layers

#Defining the normalization layer
resize_and_rescale = tf.keras.Sequential([
  layers.Resizing(img_height, img_width),
  layers.Rescaling(1./255)
])


#Augmenting the data
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
])

#Making sure to only augment the training data
train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

# %%
#Visualizing the data
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
num_classes = len(class_names)
model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),

  layers.Conv2D(16, 3, padding='same', activation='relu'),
     layers.MaxPooling2D((2,2)),
  layers.BatchNormalization(),
  layers.MaxPooling2D((2,2)),
  layers.BatchNormalization(),
    
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D((2,2)),
  layers.BatchNormalization(),
  layers.Dropout(0.2),
    
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D((2,2)),
  layers.BatchNormalization(),
  
  layers.Conv2D(128, 3, padding='same', activation='relu'),
   layers.MaxPooling2D((2,2)),
  layers.BatchNormalization(),
  layers.Dropout(0.2),
    
  layers.Conv2D(256, 3, padding='same', activation='relu'),
  layers.MaxPooling2D((2,2)),
  layers.BatchNormalization(),
  layers.Dropout(0.2),
    
  layers.Flatten(),
  layers.Dense(units = num_classes, activation='relu'),
  layers.Dropout(0.3),
  layers.Dense(units = num_classes, activation = 'softmax')
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'],
              run_eagerly= True)

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 100, 100, 3)       0
#
#  conv2d (Conv2D)             (None, 100, 100, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 16)       0
#  )
#
#  batch_normalization (BatchN  (None, 50, 50, 16)       64
#  ormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 16)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 25, 25, 16)       64
#  hNormalization)
#
#  conv2d_1 (Conv2D)           (None, 25, 25, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 32)       0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 12, 12, 32)       128
#  hNormalization)
#
#  dropout (Dropout)           (None, 12, 12, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 6, 6, 64)         256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 128)         73856
#
#  max_pooling2d_4 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 3, 3, 128)        512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 3, 3, 128)         0
#
#  conv2d_4 (Conv2D)           (None, 3, 3, 256)         295168
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  batch_normalization_5 (Batc  (None, 1, 1, 256)        1024
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 1, 1, 256)         0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 29)                7453
#
#  dropout_3 (Dropout)         (None, 29)                0
#
#  dense_1 (Dense)             (None, 29)                870
#
# =================================================================
# Total params: 402,979
# Trainable params: 401,955
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
class ClearMemory(Callback):
    def on_epoch_end(self, epoch, logs=None):
        gc.collect()
        bc.clear_session()

epochs=15
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks = ClearMemory()
)
# Out:
# Epoch 1/10
# 6960/6960 [==============================] - 1020s 147ms/step - loss: 2.6124 - accuracy: 0.2062 - val_loss: 2.6329 - val_accuracy: 0.2339
# Epoch 2/10
# 6960/6960 [==============================] - 1235s 177ms/step - loss: 1.8419 - accuracy: 0.3905 - val_loss: 2.3281 - val_accuracy: 0.3487
# Epoch 3/10
# 6960/6960 [==============================] - 990s 142ms/step - loss: 1.5249 - accuracy: 0.4852 - val_loss: 1.0297 - val_accuracy: 0.6529
# Epoch 4/10
# 6960/6960 [==============================] - 986s 142ms/step - loss: 1.3373 - accuracy: 0.5415 - val_loss: 0.8020 - val_accuracy: 0.7297
# Epoch 5/10
# 6960/6960 [==============================] - 982s 141ms/step - loss: 1.2242 - accuracy: 0.5791 - val_loss: 5.1533 - val_accuracy: 0.2226
# Epoch 6/10
# 6960/6960 [==============================] - 990s 142ms/step - loss: 1.1386 - accuracy: 0.6060 - val_loss: 1.4138 - val_accuracy: 0.5845
# Epoch 7/10
# 6960/6960 [==============================] - 995s 143ms/step - loss: 1.0782 - accuracy: 0.6271 - val_loss: 0.7297 - val_accuracy: 0.7578
# Epoch 8/10
# 6960/6960 [==============================] - 990s 142ms/step - loss: 1.0175 - accuracy: 0.6474 - val_loss: 0.4953 - val_accuracy: 0.8352
# Epoch 9/10
# 6960/6960 [==============================] - 989s 142ms/step - loss: 0.9755 - accuracy: 0.6619 - val_loss: 0.8794 - val_accuracy: 0.7039
# Epoch 10/10
# 6960/6960 [==============================] - 995s 143ms/step - loss: 0.9305 - accuracy: 0.6782 - val_loss: 0.4582 - val_accuracy: 0.8460

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
