# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization,Rescaling
from tensorflow.keras.callbacks import Callback
from tensorflow.keras import backend as bc
import gc

# %% [markdown]
# ### LOADING IN THE DATA

# %%
#Setting the batch size to be fed into the model and the image width and height
batch_size = 10
img_height = 100
img_width = 100

# %%
data_dir= r"dataset/asl_alphabet_train/asl_alphabet_train"

#Splitting the dataset into training and validation dataset
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 87000 files belonging to 29 classes.
# Using 69600 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 87000 files belonging to 29 classes.
# Using 17400 files for validation.

# %%
#Print class names
class_names = train_ds.class_names
print(len(class_names))
# Out:
# 29

# %%
#Visualizing the data
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ### PREPROCESSING THE DATA

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#Defining some preprocessing layers

#Defining the normalization layer
resize_and_rescale = tf.keras.Sequential([
  layers.Resizing(img_height, img_width),
  layers.Rescaling(1./255)
])


#Augmenting the data
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
])

#Making sure to only augment the training data
train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                num_parallel_calls=AUTOTUNE)

# %%
#Visualizing the data
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
num_classes = len(class_names)
model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),

  layers.Conv2D(16, 3, padding='same', activation='relu'),
     layers.MaxPooling2D((2,2)),
  layers.BatchNormalization(),
  layers.MaxPooling2D((2,2)),
  layers.BatchNormalization(),
    
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D((2,2)),
  layers.BatchNormalization(),
  layers.Dropout(0.2),
    
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D((2,2)),
  layers.BatchNormalization(),
  
  layers.Conv2D(128, 3, padding='same', activation='relu'),
   layers.MaxPooling2D((2,2)),
  layers.BatchNormalization(),
  layers.Dropout(0.2),
    
  layers.Conv2D(256, 3, padding='same', activation='relu'),
  layers.MaxPooling2D((2,2)),
  layers.BatchNormalization(),
  layers.Dropout(0.2),
    
  layers.Flatten(),
  layers.Dense(units = num_classes, activation='relu'),
  layers.Dropout(0.3),
  layers.Dense(units = num_classes, activation = 'softmax')
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'],
              run_eagerly= True)#Run eagerly helps reduce the RAM use of the model

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 100, 100, 3)       0
#
#  conv2d (Conv2D)             (None, 100, 100, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 50, 50, 16)       0
#  )
#
#  batch_normalization (BatchN  (None, 50, 50, 16)       64
#  ormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 25, 25, 16)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 25, 25, 16)       64
#  hNormalization)
#
#  conv2d_1 (Conv2D)           (None, 25, 25, 32)        4640
#
#  max_pooling2d_2 (MaxPooling  (None, 12, 12, 32)       0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 12, 12, 32)       128
#  hNormalization)
#
#  dropout (Dropout)           (None, 12, 12, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 6, 6, 64)         256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 128)         73856
#
#  max_pooling2d_4 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  batch_normalization_4 (Batc  (None, 3, 3, 128)        512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 3, 3, 128)         0
#
#  conv2d_4 (Conv2D)           (None, 3, 3, 256)         295168
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 256)        0
#  2D)
#
#  batch_normalization_5 (Batc  (None, 1, 1, 256)        1024
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 1, 1, 256)         0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 29)                7453
#
#  dropout_3 (Dropout)         (None, 29)                0
#
#  dense_1 (Dense)             (None, 29)                870
#
# =================================================================
# Total params: 402,979
# Trainable params: 401,955
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
#Helping reduce the RAM use of the model by clearing memory after each epoch is run
class ClearMemory(Callback):
    def on_epoch_end(self, epoch, logs=None):
        gc.collect()
        bc.clear_session()

#Number of epochs to be run
epochs=15

#Training the model
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  callbacks = ClearMemory()
)
# Out:
# Epoch 1/15
# 6960/6960 [==============================] - 1402s 201ms/step - loss: 2.6322 - accuracy: 0.2088 - val_loss: 2.3481 - val_accuracy: 0.2707
# Epoch 2/15
# 6960/6960 [==============================] - 1095s 157ms/step - loss: 1.8143 - accuracy: 0.4040 - val_loss: 1.3450 - val_accuracy: 0.5368
# Epoch 3/15
# 6960/6960 [==============================] - 1025s 147ms/step - loss: 1.4917 - accuracy: 0.4976 - val_loss: 1.3675 - val_accuracy: 0.5122
# Epoch 4/15
# 6960/6960 [==============================] - 1023s 147ms/step - loss: 1.3224 - accuracy: 0.5464 - val_loss: 1.0123 - val_accuracy: 0.6472
# Epoch 5/15
# 6960/6960 [==============================] - 949s 136ms/step - loss: 1.1995 - accuracy: 0.5857 - val_loss: 2.4093 - val_accuracy: 0.4846
# Epoch 6/15
# 6960/6960 [==============================] - 920s 132ms/step - loss: 1.1116 - accuracy: 0.6177 - val_loss: 0.5867 - val_accuracy: 0.7793
# Epoch 7/15
# 6960/6960 [==============================] - 982s 141ms/step - loss: 1.0445 - accuracy: 0.6380 - val_loss: 0.5032 - val_accuracy: 0.8164
# Epoch 8/15
# 6960/6960 [==============================] - 1077s 155ms/step - loss: 0.9863 - accuracy: 0.6544 - val_loss: 0.7885 - val_accuracy: 0.7261
# Epoch 9/15
# 6960/6960 [==============================] - 1172s 168ms/step - loss: 0.9487 - accuracy: 0.6702 - val_loss: 0.5668 - val_accuracy: 0.8083
# Epoch 10/15
# 6960/6960 [==============================] - 1007s 145ms/step - loss: 0.9092 - accuracy: 0.6837 - val_loss: 0.3714 - val_accuracy: 0.8781
# Epoch 11/15
# 6960/6960 [==============================] - 1002s 144ms/step - loss: 0.8779 - accuracy: 0.6953 - val_loss: 0.4144 - val_accuracy: 0.8551
# Epoch 12/15
# 6960/6960 [==============================] - 10962s 2s/step - loss: 0.8493 - accuracy: 0.7021 - val_loss: 0.5933 - val_accuracy: 0.7995
# Epoch 13/15
# 6960/6960 [==============================] - 988s 142ms/step - loss: 0.8229 - accuracy: 0.7133 - val_loss: 0.3541 - val_accuracy: 0.8818
# Epoch 14/15
# 6960/6960 [==============================] - 960s 138ms/step - loss: 0.8107 - accuracy: 0.7170 - val_loss: 0.3039 - val_accuracy: 0.9020
# Epoch 15/15
# 6960/6960 [==============================] - 994s 143ms/step - loss: 0.7835 - accuracy: 0.7262 - val_loss: 0.2837 - val_accuracy: 0.8979

# %%
#Plotting the training and validation accuracy and loss
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#Creating a directory to save the model
# !mkdir -p saved_model
#Saving the model
model.save('saved_model/sign-language')
# Out:
# INFO:tensorflow:Assets written to: saved_model/sign-language\assets
